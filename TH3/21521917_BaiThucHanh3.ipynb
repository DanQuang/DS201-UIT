# %% [markdown]
# ### Load Repo

# %%
# !git clone https://github.com/DanQuang/DS201
# Out:
# Cloning into 'DS201'...
# remote: Enumerating objects: 153, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 153 (delta 35), reused 72 (delta 21), pack-reused 63
# Receiving objects: 100% (153/153), 41.34 MiB | 15.25 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %% [markdown]
# ### Training

# %%
# !pip install idx2numpy torchmetrics

# %%
# !python /content/DS201/TH3/main.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Epoch 1: ---------
# 782it [00:11, 66.04it/s]
# ******************************
# Training:
# Loss: 1.1747857642
# 313it [00:04, 76.66it/s]
# ******************************
# Evaluating:
# Accuracy: 0.4550446272
# Precision: 0.4394949079
# Recall: 0.4550446272
# F1-score: 0.3932292163
# Epoch 2: ---------
# 782it [00:11, 68.78it/s]
# ******************************
# Training:
# Loss: 0.4867167389
# 313it [00:03, 97.64it/s]
# ******************************
# Evaluating:
# Accuracy: 0.4453463852
# Precision: 0.4590846896
# Recall: 0.4453463852
# F1-score: 0.4004549980
# Epoch 3: ---------
# 782it [00:11, 66.23it/s]
# ******************************
# Training:
# Loss: 0.1976269878
# 313it [00:03, 98.12it/s]
# ...
